# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("laptop_price.csv",encoding='latin-1')

# %%
df['Company'].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# ...

# %%
# Check Null Value
df.isnull().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
# Removing GB from Ram 
# Removing Kg from Weight
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS   1.37      1339.69
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %%
#Now changing the format Object to int and float
# Ram -> Int
# Weight -> Float
df['Ram'] = df['Ram'].astype('int32')
df['Weight']= df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price_euros       1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(8)
# memory usage: 112.1+ KB

# %% [markdown]
# ## Data Cleaning

# %%
#visulaizing the distribution of a single variable or column in dataset
sns.distplot(df['Price_euros'])
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\1130721552.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price_euros'])
# <Axes: xlabel='Price_euros', ylabel='Density'>

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69
# ...

# %%
df["ScreenResolution"].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
#Create one column for touch feature in laptoop
df['TouchScreen'] = df["ScreenResolution"].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  TouchScreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69            0
# ...

# %%
df['TouchScreen'].value_counts().plot(kind='bar')
# 0 = laptop without touchscreen
# 1 = Laptop with touchscreen
# Out:
# <Axes: >

# %%
#Create one more for IPS function
df['IPS'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  TouchScreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69            0    1
# ...

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#With Price
sns.barplot(x=df['IPS'],y=df['Price_euros'])
# Out:
# <Axes: xlabel='IPS', ylabel='Price_euros'>

# %%
#Now create 2 more column for resolution from ScreenResolution column
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
new
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
#2nd Column is good but 1st have some problem
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df['X_res'].head()
# Out:
# 0    IPS Panel Retina Display 2560
# 1                             1440
# 2                     Full HD 1920
# 3    IPS Panel Retina Display 2880
# 4    IPS Panel Retina Display 2560
# Name: X_res, dtype: object

# %%
df['Y_res'].head()
# Out:
# 0    1600
# 1     900
# 2    1080
# 3    1800
# 4    1600
# Name: Y_res, dtype: object

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  TouchScreen  IPS  \
# ...

# %%
#Now remove the strings in X_res column with the help of regular expression
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  TouchScreen  IPS  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price_euros       1303 non-null   float64
#  12  TouchScreen       1303 non-null   int64
#  13  IPS               1303 non-null   int64
#  14  X_res             1303 non-null   object
#  15  Y_res             1303 non-null   object
# ...

# %%
#convert both column (X_res and Y_res) in integer
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price_euros       1303 non-null   float64
#  12  TouchScreen       1303 non-null   int64
#  13  IPS               1303 non-null   int64
#  14  X_res             1303 non-null   int32
#  15  Y_res             1303 non-null   int32
# ...

# %%
# create last feature PPI (pixel per inch) with the help of X_res, Y_res and Inches columns
df['PPI'] = (((df['X_res']**2) + (df['Y_res']**2)) ** 0.5/df['Inches']).astype('float')

# %%
df.sample(5)
# Out:
#      Company              Product  TypeName  Inches  \
# 1268      HP     Stream 11-Y000na   Netbook    11.6
# 310   Lenovo   IdeaPad 720S-13IKB  Notebook    13.3
# 962     Acer  Aspire F5-573G-510L  Notebook    15.6
# 1012      HP        Elitebook 840  Notebook    14.0
# 379     Acer             Aspire 7  Notebook    15.6
#
#                  ScreenResolution                                   Cpu  Ram  \
# 1268                     1366x768  Intel Celeron Dual Core N3060 1.6GHz    2
# 310   IPS Panel Full HD 1920x1080            Intel Core i5 7200U 2.5GHz    8
# 962             Full HD 1920x1080            Intel Core i5 7200U 2.5GHz   12
# 1012            Full HD 1920x1080            Intel Core i5 7200U 2.5GHz    4
# 379             Full HD 1920x1080           Intel Core i7 7700HQ 2.8GHz    8
#
#                     Memory                      Gpu       OpSys  Weight  \
# 1268    32GB Flash Storage    Intel HD Graphics 400  Windows 10    1.17
# ...

# %%
# Drop Inches , X_res, Y_res and Screen Resolution
df.drop(columns=['ScreenResolution','Inches','X_res','Y_res'], inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_euros  TouchScreen  IPS         PPI
# 0      1339.69            0    1  226.983005
# 1       898.94            0    0  127.677940
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
#create more columns Cpu Name to the cateorgy
df['Cpu_name'] = df['Cpu'].apply(lambda x : " ".join(x.split()[0:3]))

# %%
df['Clock_Speed'] = df['Cpu'].apply(lambda x : x.split()[-1] )

# %%
df['Clock_Speed'].value_counts()
# Out:
# 2.5GHz     290
# 2.7GHz     165
# 2.8GHz     165
# 1.6GHz     133
# 2.3GHz      86
# 1.8GHz      78
# 2.6GHz      76
# 2GHz        67
# 1.1GHz      53
# 2.4GHz      52
# 2.9GHz      21
# 3GHz        19
# 2.0GHz      19
# 1.2GHz      15
# 1.44GHz     12
# 2.2GHz      11
# 1.5GHz      10
# 1.3GHz       6
# 3.6GHz       5
# 0.9GHz       4
# 3.1GHz       3
# 2.1GHz       3
# 2.50GHz      3
# 1.9GHz       2
# 1.60GHz      1
# 3.2GHz       1
# 1.0GHz       1
# 1.92GHz      1
# 2.70GHz      1
# Name: Clock_Speed, dtype: int64

# %%
#Return the GHz
def ghz(ghzs):
    last_value = ghzs.split()[-1]
    string_format = "".join(last_value)
    split_ghz =string_format.split("GHz")[0]
    return split_ghz

# %%
df["GHZ"] = df["Clock_Speed"].apply(ghz).astype(float)

# %%
df.drop(columns=["Clock_Speed"],inplace=True)

# %%
df.sample(7)
# Out:
#       Company                               Product            TypeName  \
# 910      Dell                         Latitude 5480            Notebook
# 285      Acer  SP315-51 (i7-7500U/12GB/1TB/FHD/W10)            Notebook
# 576   Toshiba                       Tecra X40-D-10H           Ultrabook
# 1084     Dell                           Vostro 3568            Notebook
# 150      Dell                         Inspiron 5577              Gaming
# 874   Samsung                            Notebook 9           Ultrabook
# 1202     Dell                         Inspiron 5579  2 in 1 Convertible
#
#                               Cpu  Ram     Memory                      Gpu  \
# 910   Intel Core i5 7440HQ 2.8GHz    8  256GB SSD    Intel HD Graphics 620
# 285    Intel Core i7 7500U 2.7GHz   12    1TB HDD    Intel HD Graphics 620
# 576    Intel Core i7 7500U 2.7GHz   16  512GB SSD    Intel HD Graphics 620
# 1084   Intel Core i5 7200U 2.5GHz    8  256GB SSD    Intel HD Graphics 620
# ...

# %%
# Create function for divide the cateogry
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu_brand'] = df['Cpu_name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_euros  TouchScreen  IPS         PPI       Cpu_name  GHZ  \
# 0      1339.69            0    1  226.983005  Intel Core i5  2.3
# ...

# %%
df['Cpu_brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# With Price
sns.barplot(x=df['Cpu_brand'], y = df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_euros  TouchScreen  IPS         PPI       Cpu_name  GHZ  \
# 0      1339.69            0    1  226.983005  Intel Core i5  2.3
# ...

# %%
#Now Drop CPU and Cpu_Name 
df.drop(columns=['Cpu','Cpu_name'],inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram               Memory  \
# 0   Apple  MacBook Pro  Ultrabook    8            128GB SSD
# 1   Apple  Macbook Air  Ultrabook    8  128GB Flash Storage
# 2      HP       250 G6   Notebook    8            256GB SSD
# 3   Apple  MacBook Pro  Ultrabook   16            512GB SSD
# 4   Apple  MacBook Pro  Ultrabook    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69            0    1
# 1        Intel HD Graphics 6000  macOS    1.34       898.94            0    0
# 2         Intel HD Graphics 620  No OS    1.86       575.00            0    0
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60            0    1
#
#           PPI  GHZ      Cpu_brand
# 0  226.983005  2.3  Intel Core i5
# 1  127.677940  1.8  Intel Core i5
# ...

# %%
# Now RAM
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#with Price
sns.barplot(x=df['Ram'], y = df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
#Now Memory
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)
df["first"] = new[0]
df["first"] = df["first"].str.strip() #for removing whitespace from each value in the selected column.

df["second"] = new[1]
df["Layer1HDD"] = df["first"].apply(lambda x : 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D','')
df["second"].fillna("0", inplace = True)



df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')
df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)



df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\3419493501.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D','')
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\3419493501.py:24: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.sample(5)
# Out:
#       Company                                Product            TypeName  Ram  \
# 1157   Lenovo                         ThinkPad T460s           Ultrabook   12
# 1217   Lenovo                      IdeaPad 320-17IKB            Notebook    8
# 978        HP      15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook    6
# 892   Samsung                             Notebook 9           Ultrabook    8
# 590      Asus  TP501UA-CJ131T (i5-7200U/8GB/1TB/W10)  2 in 1 Convertible    8
#
#         Memory                    Gpu       OpSys  Weight  Price_euros  \
# 1157   512 SSD  Intel HD Graphics 520   Windows 7    1.40       2299.0
# 1217  1000 HDD  Intel HD Graphics 620       No OS    2.80        539.0
# 978   1000 HDD  Intel HD Graphics 620  Windows 10    2.04        579.0
# 892    256 SSD  Intel HD Graphics 620  Windows 10    1.17       1699.0
# 590   1000 HDD  Intel HD Graphics 520  Windows 10    2.20        739.0
#
# ...

# %%
# Now memory 
df.drop(columns=['Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram                           Gpu  OpSys  \
# 0   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Macbook Air  Ultrabook    8        Intel HD Graphics 6000  macOS
# 2      HP       250 G6   Notebook    8         Intel HD Graphics 620  No OS
# 3   Apple  MacBook Pro  Ultrabook   16            AMD Radeon Pro 455  macOS
# 4   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros  TouchScreen  IPS         PPI  GHZ      Cpu_brand  HDD  \
# 0    1.37      1339.69            0    1  226.983005  2.3  Intel Core i5    0
# 1    1.34       898.94            0    0  127.677940  1.8  Intel Core i5    0
# 2    1.86       575.00            0    0  141.211998  2.5  Intel Core i5    0
# 3    1.83      2537.45            0    1  220.534624  2.7  Intel Core i7    0
# 4    1.37      1803.60            0    1  226.983005  3.1  Intel Core i5    0
#
#    SSD  Hybrid  Flash_Storage
# ...

# %%
df.corr()['Price_euros']
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\3238765375.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price_euros']
# Ram              0.743007
# Weight           0.210370
# Price_euros      1.000000
# TouchScreen      0.191226
# IPS              0.252208
# PPI              0.473487
# GHZ              0.430293
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price_euros, dtype: float64

# %%
# Remove hybrid and Flash Storage acc. to Correlation
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram                           Gpu  OpSys  \
# 0   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Macbook Air  Ultrabook    8        Intel HD Graphics 6000  macOS
# 2      HP       250 G6   Notebook    8         Intel HD Graphics 620  No OS
# 3   Apple  MacBook Pro  Ultrabook   16            AMD Radeon Pro 455  macOS
# 4   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros  TouchScreen  IPS         PPI  GHZ      Cpu_brand  HDD  \
# 0    1.37      1339.69            0    1  226.983005  2.3  Intel Core i5    0
# 1    1.34       898.94            0    0  127.677940  1.8  Intel Core i5    0
# 2    1.86       575.00            0    0  141.211998  2.5  Intel Core i5    0
# 3    1.83      2537.45            0    1  220.534624  2.7  Intel Core i7    0
# 4    1.37      1803.60            0    1  226.983005  3.1  Intel Core i5    0
#
#    SSD
# 0  128
# 1    0
# 2  256
# ...

# %%
#Now GPU
df["Gpu"].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
# For Brand Name Only
df['Gpu_Brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram                           Gpu  OpSys  \
# 0   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Macbook Air  Ultrabook    8        Intel HD Graphics 6000  macOS
# 2      HP       250 G6   Notebook    8         Intel HD Graphics 620  No OS
# 3   Apple  MacBook Pro  Ultrabook   16            AMD Radeon Pro 455  macOS
# 4   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros  TouchScreen  IPS         PPI  GHZ      Cpu_brand  HDD  \
# 0    1.37      1339.69            0    1  226.983005  2.3  Intel Core i5    0
# 1    1.34       898.94            0    0  127.677940  1.8  Intel Core i5    0
# 2    1.86       575.00            0    0  141.211998  2.5  Intel Core i5    0
# 3    1.83      2537.45            0    1  220.534624  2.7  Intel Core i7    0
# 4    1.37      1803.60            0    1  226.983005  3.1  Intel Core i5    0
#
#    SSD Gpu_Brand
# 0  128     Intel
# ...

# %%
df['Gpu_Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu_Brand, dtype: int64

# %%
#Remove Arm because of the 1 laptop
df = df[df['Gpu_Brand']!='ARM']

# %%
df['Gpu_Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu_Brand, dtype: int64

# %%
df.drop(columns=['Gpu'],inplace=True)
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\1111925144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram  OpSys  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    8  macOS    1.37      1803.60
#
#    TouchScreen  IPS         PPI  GHZ      Cpu_brand  HDD  SSD Gpu_Brand
# 0            0    1  226.983005  2.3  Intel Core i5    0  128     Intel
# 1            0    0  127.677940  1.8  Intel Core i5    0    0     Intel
# 2            0    0  141.211998  2.5  Intel Core i5    0  256     Intel
# 3            0    1  220.534624  2.7  Intel Core i7    0  512       AMD
# 4            0    1  226.983005  3.1  Intel Core i5    0  256     Intel

# %%
sns.barplot(x=df['Gpu_Brand'],y=df['Price_euros'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
#Now Operating System
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price_euros'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.sample(5)
# Out:
#       Company              Product   TypeName  Ram       OpSys  Weight  \
# 1018  Toshiba      Tecra Z40-C-12Z   Notebook    8  Windows 10    1.47
# 299      Asus  ZenBook UX530UQ-PRO  Ultrabook   16  Windows 10    1.63
# 576   Toshiba      Tecra X40-D-10H  Ultrabook   16  Windows 10    1.24
# 772   Toshiba      Tecra A40-C-1E5   Notebook    4  Windows 10    1.75
# 119      Asus         VivoBook S15   Notebook    8  Windows 10    1.70
#
#       Price_euros  TouchScreen  IPS         PPI  GHZ      Cpu_brand  HDD  SSD  \
# 1018       1490.0            0    1  157.350512  2.3  Intel Core i5    0  256
# 299        1468.0            0    0  141.211998  2.7  Intel Core i7    0  512
# 576        1865.0            1    0  157.350512  2.7  Intel Core i7    0  512
# 772        1020.0            0    1  111.935204  2.3  Intel Core i5    0  128
# 119        1118.0            0    0  141.211998  1.8  Intel Core i7    0  256
#
#      Gpu_Brand
# 1018     Intel
# 299     Nvidia
# 576      Intel
# ...

# %%
#Divide the operating System
def operating_system(inp):
    if inp == "Windows 10" or inp == "Windows 7" or inp == "Windows 10 S":
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No Os/Linux'

# %%
df['os'] = df['OpSys'].apply(operating_system)
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\1529886067.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['os'] = df['OpSys'].apply(operating_system)

# %%
sns.barplot(x=df['os'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.sample(5)
# Out:
#     Company                               Product  TypeName  Ram       OpSys  \
# 765    Acer                     TravelMate P238-M  Notebook    4  Windows 10
# 572      HP  15-cd005nv (A9-9420/6GB/256GB/Radeon  Notebook    6  Windows 10
# 493    Acer                              Aspire 5  Notebook    8  Windows 10
# 256      HP    15-BW094nd (A6-9220/8GB/128GB/W10)  Notebook    8  Windows 10
# 166    Acer                              Aspire 3  Notebook    4  Windows 10
#
#      Weight  Price_euros  TouchScreen  IPS         PPI  GHZ  \
# 765    1.60       655.00            0    0  117.826530  2.3
# 572    1.95       649.00            0    1  141.211998  3.0
# 493    2.20       579.00            0    0  100.454670  2.5
# 256    1.91       445.90            0    0  100.454670  2.5
# 166    2.10       363.51            0    0  100.454670  1.1
#
#                  Cpu_brand   HDD  SSD Gpu_Brand       os
# 765          Intel Core i5     0  128     Intel  Windows
# ...

# %%
df.drop(columns=['OpSys'],inplace=True)
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\3105339334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys'],inplace=True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Ram  Weight  Price_euros  TouchScreen  IPS  \
# 0   Apple  MacBook Pro  Ultrabook    8    1.37      1339.69            0    1
# 1   Apple  Macbook Air  Ultrabook    8    1.34       898.94            0    0
# 2      HP       250 G6   Notebook    8    1.86       575.00            0    0
# 3   Apple  MacBook Pro  Ultrabook   16    1.83      2537.45            0    1
# 4   Apple  MacBook Pro  Ultrabook    8    1.37      1803.60            0    1
#
#           PPI  GHZ      Cpu_brand  HDD  SSD Gpu_Brand                  os
# 0  226.983005  2.3  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  1.8  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  2.5  Intel Core i5    0  256     Intel  Others/No Os/Linux
# 3  220.534624  2.7  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  3.1  Intel Core i5    0  256     Intel                 Mac

# %%
df.corr()['Price_euros']
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\3238765375.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price_euros']
# Ram            0.742905
# Weight         0.209867
# Price_euros    1.000000
# TouchScreen    0.192917
# IPS            0.253320
# PPI            0.475368
# GHZ            0.430122
# HDD           -0.096891
# SSD            0.670660
# Name: Price_euros, dtype: float64

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
df.drop(columns=['Product'],inplace=True)
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\163803204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Product'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight  Price_euros  TouchScreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37      1339.69            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34       898.94            0    0  127.677940
# 2      HP   Notebook    8    1.86       575.00            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83      2537.45            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37      1803.60            0    1  226.983005
#
#    GHZ      Cpu_brand  HDD  SSD Gpu_Brand                  os
# 0  2.3  Intel Core i5    0  128     Intel                 Mac
# 1  1.8  Intel Core i5    0    0     Intel                 Mac
# 2  2.5  Intel Core i5    0  256     Intel  Others/No Os/Linux
# 3  2.7  Intel Core i7    0  512       AMD                 Mac
# 4  3.1  Intel Core i5    0  256     Intel                 Mac

# %%
sns.distplot(df['Price_euros'])
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\2073861339.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price_euros'])
# <Axes: xlabel='Price_euros', ylabel='Density'>

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight  Price_euros  TouchScreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37      1339.69            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34       898.94            0    0  127.677940
# 2      HP   Notebook    8    1.86       575.00            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83      2537.45            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37      1803.60            0    1  226.983005
#
#    GHZ      Cpu_brand  HDD  SSD Gpu_Brand                  os
# 0  2.3  Intel Core i5    0  128     Intel                 Mac
# 1  1.8  Intel Core i5    0    0     Intel                 Mac
# 2  2.5  Intel Core i5    0  256     Intel  Others/No Os/Linux
# 3  2.7  Intel Core i7    0  512       AMD                 Mac
# 4  3.1  Intel Core i5    0  256     Intel                 Mac

# %%
df['TypeName'].value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    120
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   object
#  1   TypeName     1302 non-null   object
#  2   Ram          1302 non-null   int32
#  3   Weight       1302 non-null   float32
#  4   Price_euros  1302 non-null   float64
#  5   TouchScreen  1302 non-null   int64
#  6   IPS          1302 non-null   int64
#  7   PPI          1302 non-null   float64
#  8   GHZ          1302 non-null   float64
#  9   Cpu_brand    1302 non-null   object
#  10  HDD          1302 non-null   int64
#  11  SSD          1302 non-null   int64
#  12  Gpu_Brand    1302 non-null   object
#  13  os           1302 non-null   object
# dtypes: float32(1), float64(3), int32(1), int64(4), object(5)
# memory usage: 142.4+ KB

# %%
cleaned = df.copy()

# %%
cleaned.head()
# Out:
#   Company   TypeName  Ram  Weight  Price_euros  TouchScreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37      1339.69            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34       898.94            0    0  127.677940
# 2      HP   Notebook    8    1.86       575.00            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83      2537.45            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37      1803.60            0    1  226.983005
#
#    GHZ      Cpu_brand  HDD  SSD Gpu_Brand                  os
# 0  2.3  Intel Core i5    0  128     Intel                 Mac
# 1  1.8  Intel Core i5    0    0     Intel                 Mac
# 2  2.5  Intel Core i5    0  256     Intel  Others/No Os/Linux
# 3  2.7  Intel Core i7    0  512       AMD                 Mac
# 4  3.1  Intel Core i5    0  256     Intel                 Mac

# %%
fig = plt.figure(figsize=(16,6))
 

ax1 = fig.add_subplot(1,2,2)
ax1.set_title("Price Distribution By Storage Type",fontdict={"color":"darkred","fontsize":20})
sns.kdeplot(x="Price_euros",data=cleaned,hue="TypeName",shade=True,label="Mean")
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\3137776720.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x="Price_euros",data=cleaned,hue="TypeName",shade=True,label="Mean")
# <Axes: title={'center': 'Price Distribution By Storage Type'}, xlabel='Price_euros', ylabel='Density'>

# %%
fig = plt.figure(figsize=(16,6))
ax0 = fig.add_subplot(1,2,2)

ax0.set_title("Price Vs Screen Size", )
sns.boxplot(x="PPI",y="Price_euros",data=cleaned,ax=ax0,palette="Blues")
ax0.set_ylabel("Price (Eur)", )
ax0.set_xlabel("Screen Size (Inches)", )
# Out:
# Text(0.5, 0, 'Screen Size (Inches)')

# %%
fig = plt.figure(figsize=(16,6))
ax1 = fig.add_subplot(1,2,2)
ax1.set_title("Price by Ram Size")
sns.barplot(estimator=np.mean, x="Ram", y="Price_euros",data=cleaned, palette="Blues", ax=ax1)
ax1.set_ylabel("")
ax1.set_xlabel("Ram (GB)")
# Out:
# Text(0.5, 0, 'Ram (GB)')

# %%
df.sample(7)
# Out:
#      Company            TypeName  Ram  Weight  Price_euros  TouchScreen  IPS  \
# 221   Lenovo  2 in 1 Convertible    8    1.74        899.0            0    1
# 707   Lenovo         Workstation   16    2.18       1855.0            0    0
# 137     Asus              Gaming    8    3.00        938.0            0    0
# 134       HP            Notebook    8    2.05        598.0            0    0
# 546   Lenovo            Notebook    4    1.87        785.0            0    0
# 1163  Lenovo            Notebook    8    2.20        459.0            0    0
# 652     Dell           Ultrabook    8    1.20       1449.9            0    0
#
#              PPI  GHZ      Cpu_brand   HDD  SSD Gpu_Brand       os
# 221   157.350512  1.6  Intel Core i5     0  256     Intel  Windows
# 707   141.211998  2.5  Intel Core i7     0  512    Nvidia  Windows
# 137   127.335675  2.5  Intel Core i5  1000  128    Nvidia  Windows
# 134   100.454670  2.7  Intel Core i7  1000    0     Intel  Windows
# ...

# %%
plt.figure(figsize=(16,10))
c = df.groupby('TypeName')['Price_euros'].mean().sort_values(ascending=False)
plt.title('Laptop By Category Average Price')
sns.barplot(y=c, x=c.index)
# Out:
# <Axes: title={'center': 'Laptop By Category Average Price'}, xlabel='TypeName', ylabel='Price_euros'>

# %%
x = df.groupby(['TypeName']).Price_euros.median().sort_values().keys()
print(x)
df['TypeName'].replace(x,[x for x in range(6)],inplace=True)
# Out:
# Index(['Netbook', 'Notebook', '2 in 1 Convertible', 'Gaming', 'Ultrabook',
#        'Workstation'],
#       dtype='object', name='TypeName')
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\1575296752.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TypeName'].replace(x,[x for x in range(6)],inplace=True)

# %%
df['TypeName'].value_counts()
# Out:
# 1    727
# 3    205
# 4    196
# 2    120
# 5     29
# 0     25
# Name: TypeName, dtype: int64

# %%
company_sales = df.groupby('Company').sum().sort_values(by = 'Price_euros', ascending = False)
company_sales
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.barplot(data = company_sales, x= company_sales.index , y= 'Price_euros')
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\3256121239.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   company_sales = df.groupby('Company').sum().sort_values(by = 'Price_euros', ascending = False)
# <Axes: xlabel='Company', ylabel='Price_euros'>

# %%
fig, ax = plt.subplots(figsize = (10,5))
sns.heatmap(df.corr(), annot = True)
plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_16532\1119985592.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   object
#  1   TypeName     1302 non-null   int64
#  2   Ram          1302 non-null   int32
#  3   Weight       1302 non-null   float32
#  4   Price_euros  1302 non-null   float64
#  5   TouchScreen  1302 non-null   int64
#  6   IPS          1302 non-null   int64
#  7   PPI          1302 non-null   float64
#  8   GHZ          1302 non-null   float64
#  9   Cpu_brand    1302 non-null   object
#  10  HDD          1302 non-null   int64
#  11  SSD          1302 non-null   int64
#  12  Gpu_Brand    1302 non-null   object
#  13  os           1302 non-null   object
# dtypes: float32(1), float64(3), int32(1), int64(5), object(4)
# memory usage: 142.4+ KB

# %%
df['Company'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['Company'].value_counts()
#
# NameError: name 'df' is not defined
